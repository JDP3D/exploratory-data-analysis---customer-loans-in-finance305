# %% [markdown]
# ### Milestone 2
#
# This file is used just to check and view the database that has been saved to disk.

# %%
from dataframe_info import DataFrameInfo
import db_utils

# load local loan csv into pandas dataframe
df = db_utils.csv_to_dataframe('loan_payments.csv')

# %%
# check size and structure of the database
df_info = DataFrameInfo()
df_info.print_shape(df)

display(df.sample(10))
# Out:
# The shape of the dataframe is (54231, 43).
#             id  member_id  loan_amount  funded_amount  funded_amount_inv  \
# 39475   798147    1003244        16000        16000.0            16000.0
# 45996   583179     749412         9600         9600.0             9575.0
# 46465   568889     731832         9600         9600.0             9575.0
# 33516  1066084    1300233         5000         5000.0             5000.0
# 19125  7874698    9596838         5000         5000.0             5000.0
# 30385  6725865    8328138        13700        13700.0            13700.0
# 20304  7689216    9390674        15000        15000.0            15000.0
# 22452  7485272    9147384         8875         8875.0             8875.0
# 28434  6904823    8546948        24000        24000.0            24000.0
# 15320  8579933   10341406         3075         3075.0             3075.0
#
#             term  int_rate  instalment grade sub_grade  ... recoveries  \
# ...
